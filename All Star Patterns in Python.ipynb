# %% [markdown]
# ## Q1.
# ![starPattern1.png](attachment:starPattern1.png)

# %%
str = "python"
length = len(str)
for i in range(length):
    for j in range(i +1):
        print(str[i], end=" ")
    print()
# Out:
# p
# y y
# t t t
# h h h h
# o o o o o
# n n n n n n

# %% [markdown]
# ------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Q2.
#
# ![starPattern2.png](attachment:starPattern2.png)

# %%
str = "python"
for i in range(6):
    for j in range(i+1):
        print(str[j], end = " ")
    print()
# Out:
# p
# p y
# p y t
# p y t h
# p y t h o
# p y t h o n

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Q3
# ![starPattern3.png](attachment:starPattern3.png)

# %%
str = "python"
for i in range(6):
    for j in range(6-i-1):
        print(" ", end = " ")
    for j in range(i+1):
        print(str[j], end=" ")
    print()
# Out:
#           p
#         p y
#       p y t
#     p y t h
#   p y t h o
# p y t h o n

# %% [markdown]
# __________________________________________________________________________________________________________

# %% [markdown]
# ## Q4.
# ![starPattern4.png](attachment:starPattern4.png)

# %%
str = "python"
for i in range(6):
    for j in range(6-i-1):
        print(" ", end = " ")
    for j in range(i+1):
        print(str[i], end=" ")
    print()
# Out:
#           p
#         y y
#       t t t
#     h h h h
#   o o o o o
# n n n n n n

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Q5
#
# ![starPattern5.png](attachment:starPattern5.png)

# %%
str = "python"
for i in range(6):
    for j in range(6-i-1):
        print(" ", end = "")
    for j in range(i+1):
        print(str[j], end=" ")
    print()
# Out:
#      p
#     p y
#    p y t
#   p y t h
#  p y t h o
# p y t h o n

# %% [markdown]
# ## Q6.
# ![starPattern6.png](attachment:starPattern6.png)

# %%
str = "python"
for i in range(6):
    for j in range(6-i-1):
        print(" ", end = "")
    for j in range(i+1):
        print("*", end=" ")
    print()
# Out:
#      *
#     * *
#    * * *
#   * * * *
#  * * * * *
# * * * * * *

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Q7.
# ![starPattern7.png](attachment:starPattern7.png)

# %%
str = "python"
for i in range(6):
    for j in range(6-i):
        print(str[j], end = " ")
    print()
# Out:
# p y t h o n
# p y t h o
# p y t h
# p y t
# p y
# p

# %% [markdown]
# ## Q8
#
# ![starPattern8.png](attachment:starPattern8.png)

# %%
str = "python"
for i in range(6):
    for j in range(6-i):
        print("*", end = " ")
    print()
# Out:
# * * * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %% [markdown]
# -------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Q9
#
# ![starPattern9-2.png](attachment:starPattern9-2.png)

# %%
for i in range(6):
    for j in range(i):
        print(" ", end=" ")
    for j in range(6-i):
        print(str[j], end = " ")
    print()
# Out:
# p y t h o n
#   p y t h o
#     p y t h
#       p y t
#         p y
#           p

# %% [markdown]
# -------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Q10

# %%
for i in range(6):
    for j in range(i):
        print(" ", end=" ")
    for j in range(6-i):
        print("*", end = " ")
    print()
# Out:
# * * * * * *
#   * * * * *
#     * * * *
#       * * *
#         * *
#           *

# %% [markdown]
# -------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Q11
# ![starPattern9-2.png](attachment:starPattern9-2.png)

# %%
for i in range(6):
    for j in range(i):
        print(" ", end ="")
    for j in range(6-i):
        print(str[i], end=" ")
    print()
# Out:
# p p p p p p
#  y y y y y
#   t t t t
#    h h h
#     o o
#      n

# %% [markdown]
# ## Q12

# %%
for i in range(6):
    for j in range(i):
        print(" ", end ="")
    for j in range(6-i):
        print("*", end=" ")
    print()
# Out:
# * * * * * *
#  * * * * *
#   * * * *
#    * * *
#     * *
#      *

# %% [markdown]
# -------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Q13
#
# ![starPattern9.png](attachment:starPattern9.png)

# %%
for i in range(6):
    for j in range(i):
        print(" ", end="")
    for j in range(6-i):
        print("*", end=" ")
    print()
    
for i in range(1,6):
    for j in range(6-i-1):
        print(" ", end="")
    for j in range(i+1):
        print("*", end=" ")
    print()
# Out:
# * * * * * *
#  * * * * *
#   * * * *
#    * * *
#     * *
#      *
#     * *
#    * * *
#   * * * *
#  * * * * *
# * * * * * *

# %% [markdown]
# ------------------------------------------------------------------------------------------------------
# ## Q12
#
# ![starPattern9.png](attachment:starPattern9.png)

# %%
for i in range(6):
    for j in range(6-i-1):
        print(" ", end ="")
    for j in range(i+1):
        print("*", end=" ")
    print()
for i in range(1,6):
    for j in range(i):
        print(" ", end="")
    for j in range(6-i):
        print("*", end=" ")
    print()
# Out:
#      *
#     * *
#    * * *
#   * * * *
#  * * * * *
# * * * * * *
#  * * * * *
#   * * * *
#    * * *
#     * *
#      *

# %% [markdown]
# ------------------------------------------------------------------------------------------------------
# ## Q13

# %%
for i in range(6):
    for j in range(i+1):
        print("*", end=" ")
    print()
for i in range(1,6):
    for j in range(6-i):
        print("*", end=" ")
    print()
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
for i in range(6):
    for j in range(6-i-1):
        print(" ", end=" ")
    for j in range(i+1):
        print("*", end=" ")
    print()
    
for i in range(1,6):
    for j in range(i):
        print(" ", end = " ")
    for j in range(6-i):
        print("*", end=" ")
    print()
# Out:
#           *
#         * *
#       * * *
#     * * * *
#   * * * * *
# * * * * * *
#   * * * * *
#     * * * *
#       * * *
#         * *
#           *
